# %%
import requests

# %%
r = requests.get("http://localhost/api/v1/patients/all",
            headers=normal_user_token_headers
        )
        current_user = r.json()

# %%
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, ForeignKey
from sqlalchemy.orm import relationship, backref, sessionmaker

from sqlalchemy.ext.associationproxy import association_proxy
from sqlalchemy.ext.declarative import declarative_base

import os
try:
    os.remove("/home/olivier/DBs/test.db") 
except:
    pass
engine = create_engine('sqlite:////home/olivier/DBs/test.db', echo=False)

Base = declarative_base()

class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String(64))

    # association proxy of "user_keywords" collection
    # to "keyword" attribute
    groups = association_proxy('user_groups', 'group')

    def __init__(self, name):
        self.name = name

class user_groups_associtations(Base):
    __tablename__ = 'user_groups_associtations'
    user_id = Column(Integer, ForeignKey('users.id'), primary_key=True)
    keyword_id = Column(Integer, ForeignKey('groups.id'), primary_key=True)
    role = Column(String(50))

    # bidirectional attribute/collection of "user"/"user_keywords"
    user = relationship("User",
                backref=backref("user_groups",
                                cascade="all, delete-orphan")
            )

    # reference to the "Keyword" object
    group = relationship("Group", backref=backref("user_groups", cascade="all, delete-orphan"))

    def __init__(self, group=None, user=None, role=None):
        self.user = user
        self.group = group
        self.role = role

class Group(Base):
    __tablename__ = 'groups'
    id = Column(Integer, primary_key=True)
    name = Column(String(64), nullable=True)

    users = association_proxy('user_groups', 'user')
    
    def __init__(self, name=None):
        self.name = name

    def __repr__(self):
        return 'Group(%s)' % repr(self.name)

# %%
Base.metadata.create_all(engine)
Session = sessionmaker(bind=engine)
session = Session()

# %%
user = User('Max')
user_groups_associtations(user=user, group=Group("test2"), role="owns")

#user.groups.append(Group("test"))
#user.user_groups[0].role = "owns"

session.add(user)
session.commit()

# %%
session.query(User).filter(User.name == "Max").all()

# %%
group = user.groups[0]
session.delete(group)
session.commit()
#session.refresh(group)

# %%
group
# Out:
# Group('test')

# %%
session.delete(user.user_groups[0])
session.commit()

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from testuser import User
from testitem import Item



owner = User(id=1, email='abc@example.com', is_active=True)
staff = User(id=123, email='efg@example.com', is_active=True, items=[
    Item(id=1, description='', owner=owner, owner_id=2, title='title')
])
print(owner)
print(staff)
# Out:
# id=1 email='abc@example.com' is_active=True items=[]
# id=123 email='efg@example.com' is_active=True items=[Item(id=1, owner_id=2, title='title', description='', owner=User(id=1, email='abc@example.com', is_active=True, items=[]))]

# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

from sqlalchemy.ext.declarative import declared_attr
from sqlalchemy import Column, Integer, String, Enum, Date, Sequence, DateTime, Boolean, ForeignKey, Table, BLOB, ARRAY, ForeignKeyConstraint, Float

from sqlalchemy.orm.exc import NoResultFound
from sqlalchemy.orm import sessionmaker, relationship
import datetime
import hashlib, binascii, os

def hash_password(password):
    """Hash a password for storing."""
    salt = hashlib.sha256(os.urandom(60)).hexdigest().encode('ascii')
    pwdhash = hashlib.pbkdf2_hmac('sha512', password.encode('utf-8'),
                                  salt, 100000)
    pwdhash = binascii.hexlify(pwdhash)
    return (salt + pwdhash).decode('ascii')


engine = create_engine('sqlite:////home/olivier/DBs/test.db', echo=True)

# %%
Base = declarative_base()

# %%
class TimestampMixin(object):
    created_at = Column(DateTime, default=datetime.datetime.utcnow)
    
    
class TableNameMixin(object):
    @declared_attr
    def __tablename__(cls):
        return cls.__name__.lower()+'s'
    
class TableIdMixin(object):
    @declared_attr
    def id(cls):
        return Column(Integer, Sequence('{}_id_seq'.format(cls.__tablename__)), primary_key=True)
    
class TableNameIdMixin(TableNameMixin, TableIdMixin):
    pass

class PersonMixin(object):
    firstname = Column(String(50), nullable=False)
    lastname = Column(String(50), nullable=False)
    
class AnnotationMixin(TimestampMixin):
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    name = Column(String(20), nullable = False)

# %%
users_groups_associations = Table('users_groups_associations', Base.metadata,
    Column('users_id', Integer, ForeignKey('users.id')),
    Column('groups_id', Integer, ForeignKey('groups.id'))
)

class User(Base, TableNameIdMixin, PersonMixin):
    email = Column(String(80), nullable=False, unique=True)
    username = Column(String(20), nullable=False, unique=True)
    password_hash = Column(String(200), nullable=False)
    
    groups = relationship(
        "Group",
        secondary=users_groups_associations,
        back_populates="users")
    window_positions = relationship("WindowPosition", back_populates="user")
    
    
    
    def __repr__(self):
        return "<User(firstname={}, lastname={}, id={})>".format(
            self.firstname, self.lastname, self.id)
    
class WindowPosition(Base, TableNameIdMixin):    
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    user = relationship("User", back_populates="window_positions")
    window_type = Column(String, nullable=False) 
    
    top_left_x = Column(Integer, nullable=False)
    top_left_y = Column(Integer, nullable=False)
    
    bot_right_x = Column(Integer, nullable=False)
    bot_right_y = Column(Integer, nullable=False)
    
class Dataset_Group_Association(Base, TableNameMixin):
    group_id = Column(Integer, ForeignKey('groups.id'), primary_key=True)
    dataset_id = Column(Integer, ForeignKey('datasets.id'), primary_key=True)
    read = Column(Boolean, nullable=False, default=False)
    write = Column(Boolean, nullable=False, default=False)
    dlt = Column(Boolean, nullable=False, default=False)
    
    group = relationship("Group", back_populates="datasets")
    dataset = relationship("Dataset", back_populates="groups")
    
class Group(Base, TableNameIdMixin):
    name = Column(String(20), nullable=False)
    users = relationship(
        "User",
        secondary=users_groups_associations,
        back_populates="groups")
    
    datasets = relationship("Dataset_Group_Association", back_populates="group")
    patients = relationship("Patient", back_populates="groups")
    
class Dataset(Base, TableNameIdMixin):
    info = Column(String(10000), nullable=False)
    name = Column(String(50))
    
    groups = relationship("Dataset_Group_Association", back_populates = "dataset")
    collections = relationship("Collection", back_populates = "dataset")
    
shares_users_associations = Table('shares_users_associations', Base.metadata,
    Column('shares_user', Integer, primary_key=True),
    Column('shares_group', Integer, primary_key=True),
    Column('shares_dataset', Integer, primary_key=True),
                                  
    Column('users_id', Integer, ForeignKey('users.id'), primary_key=True),
)
shares_users_associations.__table_args__ = (ForeignKeyConstraint(
    ['shares_user', 'shares_group', 'shares_dataset'],
    ['shares.user_id', 'shares.group_id', 'shares.dataset_id'],),)

shares_groups_associations = Table('shares_groups_associations', Base.metadata,
    Column('shares_user', Integer, primary_key=True),
    Column('shares_group', Integer, primary_key=True),
    Column('shares_dataset', Integer, primary_key=True),
    Column('groups_id', Integer, ForeignKey('groups.id'), primary_key=True)
)
shares_groups_associations.__table_args__ = (ForeignKeyConstraint(
    ['shares_user', 'shares_group', 'shares_dataset'],
    ['shares.user_id', 'shares.group_id', 'shares.dataset_id'],),)

shares_datasets_associations = Table('shares_datasets_associations', Base.metadata,
    Column('shares_user', Integer, primary_key=True),
    Column('shares_group', Integer, primary_key=True),
    Column('shares_dataset', Integer, primary_key=True),
    Column('datasets_id', Integer, ForeignKey('datasets.id'), primary_key=True)
)
shares_datasets_associations.__table_args__ = (ForeignKeyConstraint(
    ['shares_user', 'shares_group', 'shares_dataset'],
    ['shares.user_id', 'shares.group_id', 'shares.dataset_id'],),)


class Share(Base, TableNameMixin, TimestampMixin):
    user_id = Column(Integer, ForeignKey('users.id'), primary_key=True)
    group_id = Column(Integer, ForeignKey('groups.id'), primary_key=True)
    dataset_id = Column(Integer, ForeignKey('datasets.id'), primary_key=True)

collection_enfaceimage_associations = Table('collection_enfaceimage_associations', Base.metadata, 
    Column('collections_id', Integer, ForeignKey('collections.id')),
    Column('enfaceimages_id', Integer, ForeignKey('enfaceimages.id'))
)

collection_volumeimage_associations = Table('collection_volumeimage_associations', Base.metadata, 
    Column('collections_id', Integer, ForeignKey('collections.id')),
    Column('volumeimages_id', Integer, ForeignKey('volumeimages.id'))
)

class Collection(Base, TableNameIdMixin):
    """A collection holds images of one Patient
    
    A collection holds all images of one Patient which should be evaluated together. 
    For a cross-sectional study it might contain images from a single visit
    while for a longitudinal study it can contain all images in a certain timeframe.
    Images in a collection should be registered.
    """
    registered = Column(Boolean, nullable=False, default=False)
    
    # Connection to patients table
    patient_id = Column(Integer, ForeignKey('patients.id'), nullable=False)
    patient = relationship("Patient", back_populates="collections")
    
    # Connection to datasets table
    dataset_id = Column(Integer, ForeignKey('datasets.id'), nullable=False)
    dataset = relationship("Dataset", back_populates = "collections")
    
    # Connections to image tables
    enfaceimages = relationship("EnfaceImage",
                          secondary=collection_enfaceimage_associations, 
                          back_populates = "collections")    
    volumeimages = relationship("VolumeImage",
                          secondary=collection_volumeimage_associations, 
                          back_populates = "collections")
    
groups_patients_associations = Table('groups_patients_associations', Base.metadata,
    Column('patients_id', Integer, ForeignKey('patients.id'), primary_key=True),
    Column('groups_id', Integer, ForeignKey('groups.id'), primary_key=True)
)
    
class Patient(Base, TableNameIdMixin):
    pseudonym = Column(String(30), nullable=False)
    firstname = Column(String(50), nullable=True)
    lastname = Column(String(50), nullable=True)
    gender = Column(Enum('M', 'F'))
    birthday = Column(Date, nullable=False)
    
    collections = relationship("Collection", back_populates="patient")
    groups = relationship("Group", secondary=groups_patients_associations, back_populates="patients")
    
    
    enfaceimages = relationship("EnfaceImage", back_populates="patient")
    volumeimages = relationship("VolumeImage", back_populates="patient")
    
    def __repr__(self):
        return "<Patient(firstname={}, lastname={}, id={}, gender={}, birthday={})>".format(
            self.firstname, self.lastname, self.id, self.gender, self.birthday)
    
class EnfaceImage(Base, TableNameIdMixin):
    patient_id = Column(Integer, ForeignKey('patients.id'), nullable=False)
    visit_date = Column(Date, nullable=False)
    
    filepath = Column(String(500),  nullable=False)
    
    collections = relationship("Collection",
                               secondary=collection_enfaceimage_associations, 
                               back_populates="enfaceimages" )
    patient = relationship("Patient", back_populates="enfaceimages")
    
    registered_volume = relationship("VolumeImage", back_populates="localizer_image")
    
    features = relationship("Feature", back_populates="enfaceimage")
    
    area_segmentations = None
    box_segmentations = None
    registration = None
    
class VolumeImage(Base, TableNameIdMixin):
    patient_id = Column(Integer, ForeignKey('patients.id'), nullable=False)
    visit_date = Column(Date, nullable=False)
    
    slices = relationship("Slice", back_populates="volumeimage")
    
    collections = relationship("Collection",
                               secondary=collection_volumeimage_associations, 
                               back_populates="volumeimages")
    patient = relationship("Patient", back_populates="volumeimages")
    
    localizer_id = Column(Integer, ForeignKey('enfaceimages.id'))
    localizer_image = relationship("EnfaceImage", back_populates="registered_volume", uselist=False)
    
    line_segmentations = None
    area_segmentations = None
    box_segmentations = None
    registration = None
    
class Slice(Base, TableNameIdMixin):
    start_x = Column(Integer, nullable=False)
    start_y = Column(Integer, nullable=False)
    
    end_x = Column(Integer, nullable=False)
    end_y = Column(Integer, nullable=False)
    
    volumeimage_id = Column(Integer, ForeignKey('volumeimages.id'))
    volumeimage = relationship("VolumeImage", back_populates = "slices")
    
    #line_segmentations = relationship()
    #area_segmentations = relationship()
    #box_segmentations = relationship()
    
    
class Feature(Base, TableNameIdMixin, TimestampMixin):
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    user = relationship("User")
    
    enfaceimage_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    enfaceimage = relationship("EnfaceImage", back_populates="features")
    
    pos_x = Column(Integer, nullable=False)
    ps_y = Column(Integer, nullable=False) 

featurematchs_affineregs_associations = Table('featurematchs_affineregs_associations',
    Base.metadata,
    Column('featurematchs_id', Integer, ForeignKey('featurematchs.id'), primary_key=True),
    Column('affineregs_id', Integer, ForeignKey('affineregistrations.id'), primary_key=True)
)

class FeatureMatch(Base, TableNameIdMixin, TimestampMixin):
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    user = relationship("User")
    
    feature1_id = Column(Integer, ForeignKey('features.id'), nullable=False)
    feature2_id = Column(Integer, ForeignKey('features.id'), nullable=False)
    feature1 = relationship("EnfaceImage", foreign_keys=[feature1_id])
    feature2 = relationship("EnfaceImage", foreign_keys=[feature2_id])
    
    affine_registrations = relationship("AffineRegistration",
                                        secondary=featurematchs_affineregs_associations,
                                        back_populates="feature_matchs")
    
class AffineRegistration(Base, TableNameIdMixin, TimestampMixin):
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)
    user = relationship("User")
    
    feature_matchs = relationship("FeatureMatch",
                                   secondary=featurematchs_affineregs_associations,
                                   back_populates="affine_registrations")
    parameters = Column(String(250))

# %%
points_lines_associations = Table('points_lines_associations', Base.metadata,
    Column('points_id', Integer, ForeignKey('points.id'), primary_key=True),
    Column('lines_id', Integer, ForeignKey('linesegmentations.id'), primary_key=True)
)

class Point(Base, TableNameIdMixin):
    x_value = Column(Integer, nullable=False)
    y_value = Column(Integer, nullable=False)
    
class LineSegmentation(Base, TableNameIdMixin, AnnotationMixin):
    line_heigts = Column(String(8000))
    
    points = relationship("Point", secondary = points_lines_associations)
    linetype_id = Column(Integer ForeignKey("linetypes.id"))
    line_type = relationship("LineType")
    
class LineType(Base, TableNameIdMixin):
    region_acronym = Column(String(10), nullable=False)
    description = Column(String(400), nullable=False)
    position = Column(Enum("top", "bottom", "center"))    

class AreaSegmentation(Base, TableNameIdMixin, AnnotationMixin):
    area = Column(BLOB)
    top_left = Column(Integer, ForeignKey('points.id'))
    bot_right = Column(Integer, ForeignKey('points.id'))

class AreaType(Base, TableNameIdMixin):
    region_acronym = Column(String(10), nullable=False)
    description = Column(String(400), nullable=False)

class BoxSegmentation(Base, TableNameIdMixin, AnnotationMixin):
    top_left = Column(Integer, ForeignKey('points.id'))
    bot_right = Column(Integer, ForeignKey('points.id'))

class BoxType(Base, TableNameIdMixin):
    region_acronym = Column(String(10), nullable=False)
    description = Column(String(400), nullable=False)
# Out:
#   File "<ipython-input-5-e611735e8278>", line 14
#     linetype_id = Column(Integer ForeignKey("linetypes.id"))
#                                           ^
# SyntaxError: invalid syntax

# %%
    

"""
class QuadraticRegistration(Base, TableNameIdMixin, AnnotationMixin):
    fixed_id = Column(Integer, ForeignKey('enfaceimages.id'), nullable=False)
    moving_id = Column(Integer, ForeignKey('enfaceimages.id'), nullable=False)
    
    fixed = relationship("EnfaceImage", back_populates="registrations")
    moving = relationship("EnfaceImage", back_populates="registrations")
    
    matches = relationship("PointMatch",
                           secondary=None
                           back_populates="registrations")
    
    parameters = Column(ARRAY(Integer))
    
class DeformableRegistration(Base, TableNameIdMixin, AnnotationMixin):
    fixed_id = Column(Integer, ForeignKey('enfaceimages.id'), nullable=False)
    moving_id = Column(Integer, ForeignKey('enfaceimages.id'), nullable=False)
    
    fixed = relationship("EnfaceImage", back_populates="registrations")
    moving = relationship("EnfaceImage", back_populates="registrations")
    
    matches = relationship("PointMatch",
                           secondary=None
                           back_populates="registrations")
    filepath = Column(String(200))
"""

# %%
Base.metadata.create_all(engine)
# Out:
# 2020-03-27 10:14:09,924 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-03-27 10:14:09,926 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,930 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-03-27 10:14:09,931 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,933 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("users_groups_associations")
# 2020-03-27 10:14:09,936 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,939 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("users_groups_associations")
# 2020-03-27 10:14:09,941 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,942 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("users")
# 2020-03-27 10:14:09,944 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,946 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("users")
# 2020-03-27 10:14:09,947 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,948 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("windowpositions")
# 2020-03-27 10:14:09,950 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,952 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("windowpositions")
# 2020-03-27 10:14:09,954 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,955 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("dataset_group_associations")
# 2020-03-27 10:14:09,957 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,958 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("dataset_group_associations")
# 2020-03-27 10:14:09,959 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,960 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("groups")
# 2020-03-27 10:14:09,961 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,962 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("groups")
# 2020-03-27 10:14:09,964 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,965 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("datasets")
# 2020-03-27 10:14:09,966 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,968 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("datasets")
# 2020-03-27 10:14:09,973 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,976 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("shares_users_associations")
# 2020-03-27 10:14:09,978 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,980 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("shares_users_associations")
# 2020-03-27 10:14:09,981 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,983 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("shares_groups_associations")
# 2020-03-27 10:14:09,985 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,986 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("shares_groups_associations")
# 2020-03-27 10:14:09,990 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,991 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("shares_datasets_associations")
# 2020-03-27 10:14:09,993 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,994 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("shares_datasets_associations")
# 2020-03-27 10:14:09,995 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,996 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("shares")
# 2020-03-27 10:14:09,997 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:09,998 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("shares")
# 2020-03-27 10:14:09,999 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,000 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("collection_enfaceimage_associations")
# 2020-03-27 10:14:10,000 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,010 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("collection_enfaceimage_associations")
# 2020-03-27 10:14:10,011 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,013 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("collection_volumeimage_associations")
# 2020-03-27 10:14:10,015 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,017 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("collection_volumeimage_associations")
# 2020-03-27 10:14:10,018 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,021 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("collections")
# 2020-03-27 10:14:10,024 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,028 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("collections")
# 2020-03-27 10:14:10,037 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,040 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("groups_patients_associations")
# 2020-03-27 10:14:10,042 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,044 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("groups_patients_associations")
# 2020-03-27 10:14:10,046 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,048 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("patients")
# 2020-03-27 10:14:10,049 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,050 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("patients")
# 2020-03-27 10:14:10,052 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,058 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("enfaceimages")
# 2020-03-27 10:14:10,059 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,062 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("enfaceimages")
# 2020-03-27 10:14:10,063 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,065 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("volumeimages")
# 2020-03-27 10:14:10,066 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,068 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("volumeimages")
# 2020-03-27 10:14:10,069 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,071 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("slices")
# 2020-03-27 10:14:10,072 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,075 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("slices")
# 2020-03-27 10:14:10,077 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,078 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("features")
# 2020-03-27 10:14:10,079 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,081 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("features")
# 2020-03-27 10:14:10,082 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,087 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("featurematchs_affineregs_associations")
# 2020-03-27 10:14:10,091 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,094 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("featurematchs_affineregs_associations")
# 2020-03-27 10:14:10,095 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,097 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("featurematchs")
# 2020-03-27 10:14:10,098 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,100 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("featurematchs")
# 2020-03-27 10:14:10,101 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,107 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("affineregistrations")
# 2020-03-27 10:14:10,108 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,114 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("affineregistrations")
# 2020-03-27 10:14:10,115 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,119 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE users (
# 	firstname VARCHAR(50) NOT NULL,
# 	lastname VARCHAR(50) NOT NULL,
# 	email VARCHAR(80) NOT NULL,
# 	username VARCHAR(20) NOT NULL,
# 	password_hash VARCHAR(200) NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	UNIQUE (email),
# 	UNIQUE (username)
# )
#
#
# 2020-03-27 10:14:10,122 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,133 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,138 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE groups (
# 	name VARCHAR(20) NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2020-03-27 10:14:10,140 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,152 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,153 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE datasets (
# 	info VARCHAR(10000) NOT NULL,
# 	name VARCHAR(50),
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2020-03-27 10:14:10,154 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,169 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,170 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE patients (
# 	pseudonym VARCHAR(30) NOT NULL,
# 	firstname VARCHAR(50),
# 	lastname VARCHAR(50),
# 	gender VARCHAR(1),
# 	birthday DATE NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	CHECK (gender IN ('M', 'F'))
# )
#
#
# 2020-03-27 10:14:10,171 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,186 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,188 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE users_groups_associations (
# 	users_id INTEGER,
# 	groups_id INTEGER,
# 	FOREIGN KEY(users_id) REFERENCES users (id),
# 	FOREIGN KEY(groups_id) REFERENCES groups (id)
# )
#
#
# 2020-03-27 10:14:10,189 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,203 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,206 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE windowpositions (
# 	user_id INTEGER NOT NULL,
# 	window_type VARCHAR NOT NULL,
# 	top_left_x INTEGER NOT NULL,
# 	top_left_y INTEGER NOT NULL,
# 	bot_right_x INTEGER NOT NULL,
# 	bot_right_y INTEGER NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id)
# )
#
#
# 2020-03-27 10:14:10,207 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,219 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,221 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE dataset_group_associations (
# 	group_id INTEGER NOT NULL,
# 	dataset_id INTEGER NOT NULL,
# 	read BOOLEAN NOT NULL,
# 	write BOOLEAN NOT NULL,
# 	dlt BOOLEAN NOT NULL,
# 	PRIMARY KEY (group_id, dataset_id),
# 	FOREIGN KEY(group_id) REFERENCES groups (id),
# 	FOREIGN KEY(dataset_id) REFERENCES datasets (id),
# 	CHECK (read IN (0, 1)),
# 	CHECK (write IN (0, 1)),
# 	CHECK (dlt IN (0, 1))
# )
#
#
# 2020-03-27 10:14:10,223 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,236 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,238 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE shares_users_associations (
# 	shares_user INTEGER NOT NULL,
# 	shares_group INTEGER NOT NULL,
# 	shares_dataset INTEGER NOT NULL,
# 	users_id INTEGER NOT NULL,
# 	PRIMARY KEY (shares_user, shares_group, shares_dataset, users_id),
# 	FOREIGN KEY(users_id) REFERENCES users (id)
# )
#
#
# 2020-03-27 10:14:10,239 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,253 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,254 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE shares_groups_associations (
# 	shares_user INTEGER NOT NULL,
# 	shares_group INTEGER NOT NULL,
# 	shares_dataset INTEGER NOT NULL,
# 	groups_id INTEGER NOT NULL,
# 	PRIMARY KEY (shares_user, shares_group, shares_dataset, groups_id),
# 	FOREIGN KEY(groups_id) REFERENCES groups (id)
# )
#
#
# 2020-03-27 10:14:10,255 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,270 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,273 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE shares_datasets_associations (
# 	shares_user INTEGER NOT NULL,
# 	shares_group INTEGER NOT NULL,
# 	shares_dataset INTEGER NOT NULL,
# 	datasets_id INTEGER NOT NULL,
# 	PRIMARY KEY (shares_user, shares_group, shares_dataset, datasets_id),
# 	FOREIGN KEY(datasets_id) REFERENCES datasets (id)
# )
#
#
# 2020-03-27 10:14:10,274 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,287 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,290 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE shares (
# 	created_at DATETIME,
# 	user_id INTEGER NOT NULL,
# 	group_id INTEGER NOT NULL,
# 	dataset_id INTEGER NOT NULL,
# 	PRIMARY KEY (user_id, group_id, dataset_id),
# 	FOREIGN KEY(user_id) REFERENCES users (id),
# 	FOREIGN KEY(group_id) REFERENCES groups (id),
# 	FOREIGN KEY(dataset_id) REFERENCES datasets (id)
# )
#
#
# 2020-03-27 10:14:10,291 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,304 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,306 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE collections (
# 	registered BOOLEAN NOT NULL,
# 	patient_id INTEGER NOT NULL,
# 	dataset_id INTEGER NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	CHECK (registered IN (0, 1)),
# 	FOREIGN KEY(patient_id) REFERENCES patients (id),
# 	FOREIGN KEY(dataset_id) REFERENCES datasets (id)
# )
#
#
# 2020-03-27 10:14:10,307 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,321 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,322 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE groups_patients_associations (
# 	patients_id INTEGER NOT NULL,
# 	groups_id INTEGER NOT NULL,
# 	PRIMARY KEY (patients_id, groups_id),
# 	FOREIGN KEY(patients_id) REFERENCES patients (id),
# 	FOREIGN KEY(groups_id) REFERENCES groups (id)
# )
#
#
# 2020-03-27 10:14:10,324 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,338 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,340 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE enfaceimages (
# 	patient_id INTEGER NOT NULL,
# 	visit_date DATE NOT NULL,
# 	filepath VARCHAR(500) NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(patient_id) REFERENCES patients (id)
# )
#
#
# 2020-03-27 10:14:10,342 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,355 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,357 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE features (
# 	created_at DATETIME,
# 	user_id INTEGER NOT NULL,
# 	enfaceimage_id INTEGER NOT NULL,
# 	pos_x INTEGER NOT NULL,
# 	ps_y INTEGER NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id),
# 	FOREIGN KEY(enfaceimage_id) REFERENCES users (id)
# )
#
#
# 2020-03-27 10:14:10,358 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,372 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,373 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE affineregistrations (
# 	created_at DATETIME,
# 	user_id INTEGER NOT NULL,
# 	parameters VARCHAR(250),
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id)
# )
#
#
# 2020-03-27 10:14:10,377 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,389 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,390 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE collection_enfaceimage_associations (
# 	collections_id INTEGER,
# 	enfaceimages_id INTEGER,
# 	FOREIGN KEY(collections_id) REFERENCES collections (id),
# 	FOREIGN KEY(enfaceimages_id) REFERENCES enfaceimages (id)
# )
#
#
# 2020-03-27 10:14:10,391 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,406 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,409 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE volumeimages (
# 	patient_id INTEGER NOT NULL,
# 	visit_date DATE NOT NULL,
# 	localizer_id INTEGER,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(patient_id) REFERENCES patients (id),
# 	FOREIGN KEY(localizer_id) REFERENCES enfaceimages (id)
# )
#
#
# 2020-03-27 10:14:10,413 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,424 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,426 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE featurematchs (
# 	created_at DATETIME,
# 	user_id INTEGER NOT NULL,
# 	feature1_id INTEGER NOT NULL,
# 	feature2_id INTEGER NOT NULL,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(user_id) REFERENCES users (id),
# 	FOREIGN KEY(feature1_id) REFERENCES features (id),
# 	FOREIGN KEY(feature2_id) REFERENCES features (id)
# )
#
#
# 2020-03-27 10:14:10,428 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,441 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,442 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE collection_volumeimage_associations (
# 	collections_id INTEGER,
# 	volumeimages_id INTEGER,
# 	FOREIGN KEY(collections_id) REFERENCES collections (id),
# 	FOREIGN KEY(volumeimages_id) REFERENCES volumeimages (id)
# )
#
#
# 2020-03-27 10:14:10,445 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,459 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,460 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE slices (
# 	start_x INTEGER NOT NULL,
# 	start_y INTEGER NOT NULL,
# 	end_x INTEGER NOT NULL,
# 	end_y INTEGER NOT NULL,
# 	volumeimage_id INTEGER,
# 	id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(volumeimage_id) REFERENCES volumeimages (id)
# )
#
#
# 2020-03-27 10:14:10,461 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,476 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-27 10:14:10,477 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE featurematchs_affineregs_associations (
# 	featurematchs_id INTEGER NOT NULL,
# 	affineregs_id INTEGER NOT NULL,
# 	PRIMARY KEY (featurematchs_id, affineregs_id),
# 	FOREIGN KEY(featurematchs_id) REFERENCES featurematchs (id),
# 	FOREIGN KEY(affineregs_id) REFERENCES affineregistrations (id)
# )
#
#
# 2020-03-27 10:14:10,478 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-27 10:14:10,493 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
def create_user(fname, lname, uname, email, pw, session):
    new_user = User(firstname=fname, lastname=lname, username=uname, email=email,
                    password_hash=hash_password(pw))
    
    for groupname in [uname, "all"]:
        add_user_to_group(new_user, groupname)
        
    session.add(new_user)
    session.commit()
    
def add_user_to_group(user, groupname):
    query = session.query(Group).filter(Group.name == groupname)
    
    try:
        group = query.one()
        user.groups.append(group)
        
    except NoResultFound:
        user.groups.append(Group(name=groupname))
        
def create_dataset(name, info, groups):
    new_dataset = Dataset(name=name, info=info)
    
def add_visit_to_dataset():
    pass

# %%
Session = sessionmaker(bind=engine)
session = Session()

create_user("Donald", "Duck", "donald", "donald@duck.ente", "quack", session)
create_user("Max", "Mustermann", "max", "max@mustermann.muster", "test", session)
# Out:
# ---------------------------------------------------------------------------
# NoForeignKeysError                        Traceback (most recent call last)
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/relationships.py in _determine_joins(self)
#    2453                         a_subset=self.parent_local_selectable,
# -> 2454                         consider_as_foreign_keys=consider_as_foreign_keys,
#    2455                     )
#
# <string> in join_condition(a, b, ignore_nonexistent_tables, a_subset, consider_as_foreign_keys)
#
# <string> in _join_condition(cls, a, b, ignore_nonexistent_tables, a_subset, consider_as_foreign_keys)
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     127
# --> 128             return fn(*args, **kwargs)
#     129
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/sql/selectable.py in _join_condition(cls, a, b, ignore_nonexistent_tables, a_subset, consider_as_foreign_keys)
#     946                 "between '%s' and '%s'.%s"
# --> 947                 % (a.description, b.description, hint)
#     948             )
#
# NoForeignKeysError: Can't find any foreign key relationships between 'groups' and 'patients'.
#
# During handling of the above exception, another exception occurred:
#
# NoForeignKeysError                        Traceback (most recent call last)
# <ipython-input-9-80ebc93c73b7> in <module>
#       2 session = Session()
#       3
# ----> 4 create_user("Donald", "Duck", "donald", "donald@duck.ente", "quack", session)
#       5 create_user("Max", "Mustermann", "max", "max@mustermann.muster", "test", session)
#
# <ipython-input-7-4c8e6172b6ba> in create_user(fname, lname, uname, email, pw, session)
#       1 def create_user(fname, lname, uname, email, pw, session):
#       2     new_user = User(firstname=fname, lastname=lname, username=uname, email=email,
# ----> 3                     password_hash=hash_password(pw))
#       4
#       5     for groupname in [uname, "all"]:
#
# <string> in __init__(self, **kwargs)
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/instrumentation.py in _new_state_if_none(self, instance)
#     374             )._new_state_if_none(instance)
#     375         else:
# --> 376             state = self._state_constructor(instance, self)
#     377             self._state_setter(instance, state)
#     378             return state
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py in __get__(self, obj, cls)
#     853         if obj is None:
#     854             return self
# --> 855         obj.__dict__[self.__name__] = result = self.fget(obj)
#     856         return result
#     857
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/instrumentation.py in _state_constructor(self)
#     200     @util.memoized_property
#     201     def _state_constructor(self):
# --> 202         self.dispatch.first_init(self, self.class_)
#     203         return state.InstanceState
#     204
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/event/attr.py in __call__(self, *args, **kw)
#     320             fn(*args, **kw)
#     321         for fn in self.listeners:
# --> 322             fn(*args, **kw)
#     323
#     324     def __len__(self):
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in _event_on_first_init(manager, cls)
#    3359     if instrumenting_mapper:
#    3360         if Mapper._new_mappers:
# -> 3361             configure_mappers()
#    3362
#    3363
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in configure_mappers()
#    3247                 if not mapper.configured:
#    3248                     try:
# -> 3249                         mapper._post_configure_properties()
#    3250                         mapper._expire_memoizations()
#    3251                         mapper.dispatch.mapper_configured(
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/mapper.py in _post_configure_properties(self)
#    1945
#    1946             if prop.parent is self and not prop._configure_started:
# -> 1947                 prop.init()
#    1948
#    1949             if prop._configure_finished:
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/interfaces.py in init(self)
#     194         """
#     195         self._configure_started = True
# --> 196         self.do_init()
#     197         self._configure_finished = True
#     198
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/relationships.py in do_init(self)
#    1913         self._check_conflicts()
#    1914         self._process_dependent_arguments()
# -> 1915         self._setup_join_conditions()
#    1916         self._check_cascade_settings(self._cascade)
#    1917         self._post_init()
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/relationships.py in _setup_join_conditions(self)
#    1993             prop=self,
#    1994             support_sync=not self.viewonly,
# -> 1995             can_be_synced_fn=self._columns_are_mapped,
#    1996         )
#    1997         self.primaryjoin = jc.primaryjoin
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/relationships.py in __init__(self, parent_persist_selectable, child_persist_selectable, parent_local_selectable, child_local_selectable, primaryjoin, secondary, secondaryjoin, parent_equivalents, child_equivalents, consider_as_foreign_keys, local_remote_pairs, remote_side, self_referential, prop, support_sync, can_be_synced_fn)
#    2337         self.support_sync = support_sync
#    2338         self.can_be_synced_fn = can_be_synced_fn
# -> 2339         self._determine_joins()
#    2340         self._sanitize_joins()
#    2341         self._annotate_fks()
#
# ~/Devel/venvs/eyepy/lib/python3.6/site-packages/sqlalchemy/orm/relationships.py in _determine_joins(self)
#    2474                     "Ensure that referencing columns are associated "
#    2475                     "with a ForeignKey or ForeignKeyConstraint, or "
# -> 2476                     "specify a 'primaryjoin' expression." % self.prop
#    2477                 )
#    2478         except sa_exc.AmbiguousForeignKeysError:
#
# NoForeignKeysError: Could not determine join condition between parent/child tables on relationship Group.patients - there are no foreign keys linking these tables.  Ensure that referencing columns are associated with a ForeignKey or ForeignKeyConstraint, or specify a 'primaryjoin' expression.

# %%
query = session.query("groups").filter(Groups.name == group_name)
query.one()

# %%
new_user = User(firstname="Max", lastname="Mustermann", username="max", 
                email="max@mustermann.muster", password_hash=hash_password("test"))
new_user.groups = [Group(name="max"), Group(name="all")]
session.add(new_user)
session.commit()

# %%
class Patient(Base, TableNameIdMixin, PersonMixin):
    gender = Column(Enum('M', 'F'))
    birthday = Column(Date, nullable=False)
    
    def __repr__(self):
        return "<Patient(firstname={}, lastname={}, id={}, gender={}, birthday={})>".format(
            self.firstname, self.lastname, self.id, self.gender, self.birthday)
    
class Visit(Base, TableNameIdMixin):
    patient_id = Column(Integer, ForeignKey('patients.id'), nullable=False)
    visit_date = Column(Date, nullable=False)    

class Image(Base, TableNameIdMixin):
    patient_id = Column(Integer, ForeignKey('patients.id'), nullable=False)
    visit_id = Column(Integer, ForeignKey('visits.id'), nullable=False)
    filepath = Column(String(500),  nullable=False)
    
class ImageMeta(Base, TableNameIdMixin):
    modality = Column(Enum('CFP', 'OCT', 'NIR'),  nullable=False)
    eye = Column(Enum('Left', 'Right'),  nullable=False)
    image_id = None
    
class Registration(Base, TableNameIdMixin):
    image1_id = Column(Integer, ForeignKey('images.id'), nullable=False)
    image2_id = Column(Integer, ForeignKey('images.id'), nullable=False)
    registration_type = None
    parameters = None
    
    user_id = Column(Integer, ForeignKey('users.id'), nullable=False)    
    user = relationship("User", foreign_keys=[user_id])
    
class Correspondence(Base, TableNameIdMixin, TimestampMixin):
    registration_id = Column(Integer, ForeignKey('registrations.id'), nullable=False)
    point1_id = Column(Integer, ForeignKey('points.id'), nullable=False)
    point2_id = Column(Integer, ForeignKey('points.id'), nullable=False)
    
    
    registration = relationship("Registration", foreign_keys=[registration_id])
    point1 = relationship("Point", foreign_keys=[point1_id])
    point2 = relationship("Point", foreign_keys=[point2_id])
    

class Point(Base, TableNameIdMixin)
    xvalue = Column(Integer, nullable=False)
    yvalue = Column(Integer, nullable=False)
    
    

class LineSegmentation(Base, TableNameIdMixin):
    image_id = None
    
    # RPE, HRF, Fovea ...
    region = None
    
    # Guideline 
    guideline = None    
    
class AreaSegmentation(Base, TableNameIdMixin):
    pass
    
class Shapesegmentation(Base, TableNameIdMixin):
    pass
